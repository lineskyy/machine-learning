# %% [markdown]
# # 컴피티션 규칙
# - 1등팀 10만원
# - 2등팀 5만원
# - 3등부터는 고생 많았어요
# - 외부데이터 사용 금지
# - 데이터 유출 금지
# - 최종 선택한 점수에 대한 파일은 다음과 같이 제출할것
#     - 구매기록 데이터에서 특성 추출하는 파일
#     - 모델링(특성선택,스케일링 등과같은 전처리 및 학습및 예측파일 생성) 하는 파일
#     - 팀원들의 테스트데이터에 대한 예측파일을 앙상블하는 파일
# - 9월23일 12:30(PM) 까지 제출 가능
# - 컴피티션 접속 주소
#     - https://www.kaggle.com/t/9f93417de0e0445893436faa5ad82774

# %% [markdown]
# - category_encoders 설치

# %%
# !pip install category_encoders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting category_encoders
#   Downloading category_encoders-2.5.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 2.5 MB/s
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.21.6)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.3.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.7.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.5->category_encoders) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.5.0

# %% [markdown]
# - 구글드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - 데이터 경로및 시드고정

# %%
DATA_PATH = "/content/drive/MyDrive/01-python/data/2022_ML_project/data/"
SEED = 42

# %% [markdown]
# - 라이브러리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import category_encoders as ce

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.feature_selection import SelectPercentile

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# %% [markdown]
# - 데이터 불러오기

# %%
ft_train = pd.read_csv(f"{DATA_PATH}ft_train.csv") # 학습 데이터
target_train = pd.read_csv(f"{DATA_PATH}target_train.csv") # 학습데이터 정답

ft_test = pd.read_csv(f"{DATA_PATH}ft_test.csv") # 테스트 데이터
sample_submission = pd.read_csv(f"{DATA_PATH}sample_submission.csv") # 제출파일

# %% [markdown]
# - 테스트 데이터 피쳐추가

# %% [markdown]
# ## pd.pivot_table 을 이용해서 피쳐 추가하기

# %% [markdown]
# - 각 고객번호에 대하여 중분류별 구매 개수

# %%
# train_tmp = pd.pivot_table(ft_train,index="고객번호",columns="중분류수",values="총구매액",aggfunc="count",fill_value=0).reset_index()
# ft_train = ft_train.merge(train_tmp,how="left",on="고객번호")

# %% [markdown]
# - 위에 피쳐에 경우 테스트데이터에 추가시 주의해야한다.
# - 고객별로 중분류에 대한 구매 종류가 다르기 때문에 train에는 없는 중분류가 카운팅 되거나 train 에는 있지만 test에는 있는 중분류가 카운팅 될수도 있다.
# - 학습데이터와 테스트데이터에 피쳐는 동일해야한다.

# %% [markdown]
# - 테스트 데이터 특성 추출

# %%
# test_tmp = pd.pivot_table(ft_test,index="고객번호",columns="중분류수",values="총구매액",aggfunc="count",fill_value=0).reset_index()
# test_tmp.head()

# %% [markdown]
# - 학습데이터에서 뽑아낸 특성 컬럼을 기준으로 테스트데이터도 맞춰줘야함

# %%
# for col in train_tmp.columns:
#     if col not in test_tmp.columns:# 학습피쳐에는 있으나 테스트피쳐에는 없는 컬럼
#         test_tmp[col] = 0 # 0으로 채우기

# # 학습피쳐와 컬럼및 컬럼 순서 맞추기
# test_tmp = test_tmp[train_tmp.columns]

# %%
# ft_test = ft_test.merge(test_tmp,how="left",on="고객번호")

# %%
ft_train.shape , ft_test.shape
# Out:
# ((2554, 498), (946, 498))

# %% [markdown]
# - 결측치 채우기

# %%
ft_train.shape , ft_test.shape
# Out:
# ((2554, 498), (946, 498))

# %%
# me_tr = ft_train.median()
# me_ts = ft_test.median()

# %%
ft_train = ft_train.fillna(0)
ft_test = ft_test.fillna(0)

# %%
ft_train.isnull().sum().sum() , ft_test.isnull().sum().sum()
# Out:
# (0, 0)

# %% [markdown]
# - 범주형 인코딩하기

# %%
ft_train.select_dtypes("object").nunique()
# Out:
# 주구매지점      24
# 주구매중분류    169
# 주구매대분류     40
# 월방문최빈달    117
# 주환불대분류    345
# dtype: int64

# %%
cols = ["주구매지점","주구매대분류","월방문최빈달","주환불대분류"]
enc = ce.one_hot.OneHotEncoder() 

ft_train = pd.concat([
    ft_train,
    enc.fit_transform(ft_train[cols])
],axis=1).drop(columns=cols)

ft_test = pd.concat([
    ft_test,
    enc.transform(ft_test[cols])
],axis=1).drop(columns=cols)

# %%
cols = ["주구매중분류"]
enc = ce.count.CountEncoder()

ft_train = pd.concat([
    ft_train,
    enc.fit_transform(ft_train[cols]).add_suffix("_cnt")
],axis=1).drop(columns=cols)

ft_test = pd.concat([
    ft_test,
    enc.transform(ft_test[cols]).add_suffix("_cnt")
],axis=1).drop(columns=cols)

# %% [markdown]
# - 학습 데이터 , 정답 데이터, 테스트 데이터

# %% [markdown]
# - 스케일링

# %%
ft_train == np.inf
# Out:
#        고객번호   내점일수   구매주기  주말방문비율  주구매요일  봄구매비율  여름구매비율  가을구매비율  겨울구매비율  \
# 0     False  False  False   False  False  False   False   False   False
# 1     False  False  False   False  False  False   False   False   False
# 2     False  False  False   False  False  False   False   False   False
# 3     False  False  False   False  False  False   False   False   False
# 4     False  False  False   False  False  False   False   False   False
# ...     ...    ...    ...     ...    ...    ...     ...     ...     ...
# 2549  False  False  False   False  False  False   False   False   False
# 2550  False  False  False   False  False  False   False   False   False
# 2551  False  False  False   False  False  False   False   False   False
# 2552  False  False  False   False  False  False   False   False   False
# 2553  False  False  False   False  False  False   False   False   False
#
#       일평균구매건수  ...  주환불대분류_337  주환불대분류_338  주환불대분류_339  주환불대분류_340  \
# 0       False  ...       False       False       False       False
# 1       False  ...       False       False       False       False
# 2       False  ...       False       False       False       False
# 3       False  ...       False       False       False       False
# 4       False  ...       False       False       False       False
# ...       ...  ...         ...         ...         ...         ...
# 2549    False  ...       False       False       False       False
# 2550    False  ...       False       False       False       False
# 2551    False  ...       False       False       False       False
# 2552    False  ...       False       False       False       False
# 2553    False  ...       False       False       False       False
#
#       주환불대분류_341  주환불대분류_342  주환불대분류_343  주환불대분류_344  주환불대분류_345  주구매중분류_cnt
# 0          False       False       False       False       False       False
# 1          False       False       False       False       False       False
# 2          False       False       False       False       False       False
# 3          False       False       False       False       False       False
# 4          False       False       False       False       False       False
# ...          ...         ...         ...         ...         ...         ...
# 2549       False       False       False       False       False       False
# 2550       False       False       False       False       False       False
# 2551       False       False       False       False       False       False
# 2552       False       False       False       False       False       False
# 2553       False       False       False       False       False       False
#
# [2554 rows x 1020 columns]

# %%
mask = (ft_train == np.inf).sum() > 0
(ft_train == np.inf).sum()[mask]
mask2 = ft_train["지표"] == np.inf
ft_train.loc[mask2,"지표"] = 0
mask = (ft_test == np.inf).sum() > 0
(ft_test == np.inf).sum()[mask]
mask2 = ft_test["지표"] == np.inf
ft_test.loc[mask2,"지표"] = 0

# %%
train = ft_train.iloc[:,1:]
target = target_train.iloc[:,1]

test = ft_test.iloc[:,1:]

# %%
cv = KFold(n_splits=5, shuffle=True, random_state=SEED)

# %%
# cv_scores = [] 
# for p in tqdm(range(5,96,1)): 
#     select = SelectPercentile(percentile=p)   
#     select.fit(train,target) 
#     model = LogisticRegression(random_state=SEED) 
#     scores = cross_val_score(model,select.transform(train),target,cv = cv ,scoring='roc_auc',n_jobs = -1)
#     cv_scores.append( [p,scores.mean()] ) 

# cv_scores = np.array(cv_scores) 
# idx = np.argmax(cv_scores[:,1]) 
# best_score = cv_scores[idx] 
# best_score

# %%
# select = SelectPercentile(percentile=best_score[0])
# select.fit(train,target)
# train = select.transform(train)
# test = select.transform(test)
# train.shape , test.shape

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(random_state=SEED)
model.fit(train,target)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression(random_state=42)

# %%
from sklearn.model_selection import KFold

cv = KFold(n_splits=5, shuffle=True, random_state=SEED)

model_list = []
score_list = []
for tri,vai in cv.split(train):
    # 학습데이터
    x_train = train.iloc[tri]
    y_train = target.iloc[tri]
    # 검증데이터
    x_valid = train.iloc[vai]
    y_valid = target.iloc[vai]
    
    # 모델 학습
    model = XGBClassifier(random_state=SEED,n_estimators=1000)
    model.fit(x_train,y_train , eval_set = [(x_valid,y_valid)],early_stopping_rounds=100) #early_stopping_rounds 50 회 이상 개선이없으면 n_estimators(부스팅) 을 멈추겠다,eval_set 부스팅될떄마다 검증셋 검증

    pred = model.predict_proba(x_valid)[:,1] 
    score = roc_auc_score(y_valid,pred) 
    score_list.append(score) 
    model_list.append(model) 

score_list
# Out:
# [0]	validation_0-error:0.305284
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.303327
# [2]	validation_0-error:0.311155
# [3]	validation_0-error:0.317025
# [4]	validation_0-error:0.303327
# [5]	validation_0-error:0.293542
# [6]	validation_0-error:0.295499
# [7]	validation_0-error:0.30137
# [8]	validation_0-error:0.291585
# [9]	validation_0-error:0.295499
# [10]	validation_0-error:0.291585
# [11]	validation_0-error:0.287671
# [12]	validation_0-error:0.283757
# [13]	validation_0-error:0.283757
# [14]	validation_0-error:0.289628
# [15]	validation_0-error:0.287671
# [16]	validation_0-error:0.291585
# [17]	validation_0-error:0.293542
# [18]	validation_0-error:0.291585
# [19]	validation_0-error:0.287671
# [20]	validation_0-error:0.287671
# [21]	validation_0-error:0.287671
# [22]	validation_0-error:0.283757
# [23]	validation_0-error:0.2818
# [24]	validation_0-error:0.2818
# [25]	validation_0-error:0.279843
# [26]	validation_0-error:0.279843
# [27]	validation_0-error:0.285714
# [28]	validation_0-error:0.279843
# [29]	validation_0-error:0.2818
# [30]	validation_0-error:0.2818
# [31]	validation_0-error:0.279843
# [32]	validation_0-error:0.2818
# [33]	validation_0-error:0.2818
# [34]	validation_0-error:0.2818
# [35]	validation_0-error:0.279843
# [36]	validation_0-error:0.277887
# [37]	validation_0-error:0.287671
# [38]	validation_0-error:0.279843
# [39]	validation_0-error:0.2818
# [40]	validation_0-error:0.283757
# [41]	validation_0-error:0.2818
# [42]	validation_0-error:0.283757
# [43]	validation_0-error:0.283757
# [44]	validation_0-error:0.283757
# [45]	validation_0-error:0.279843
# [46]	validation_0-error:0.27593
# [47]	validation_0-error:0.279843
# [48]	validation_0-error:0.279843
# [49]	validation_0-error:0.277887
# [50]	validation_0-error:0.27593
# [51]	validation_0-error:0.277887
# [52]	validation_0-error:0.270059
# [53]	validation_0-error:0.270059
# [54]	validation_0-error:0.268102
# [55]	validation_0-error:0.268102
# [56]	validation_0-error:0.268102
# [57]	validation_0-error:0.270059
# [58]	validation_0-error:0.268102
# [59]	validation_0-error:0.270059
# [60]	validation_0-error:0.268102
# [61]	validation_0-error:0.273973
# [62]	validation_0-error:0.273973
# [63]	validation_0-error:0.27593
# [64]	validation_0-error:0.27593
# [65]	validation_0-error:0.277887
# [66]	validation_0-error:0.277887
# [67]	validation_0-error:0.27593
# [68]	validation_0-error:0.273973
# [69]	validation_0-error:0.272016
# [70]	validation_0-error:0.273973
# [71]	validation_0-error:0.273973
# [72]	validation_0-error:0.27593
# [73]	validation_0-error:0.27593
# [74]	validation_0-error:0.27593
# [75]	validation_0-error:0.277887
# [76]	validation_0-error:0.279843
# [77]	validation_0-error:0.285714
# [78]	validation_0-error:0.285714
# [79]	validation_0-error:0.283757
# [80]	validation_0-error:0.283757
# [81]	validation_0-error:0.2818
# [82]	validation_0-error:0.2818
# [83]	validation_0-error:0.283757
# [84]	validation_0-error:0.283757
# [85]	validation_0-error:0.2818
# [86]	validation_0-error:0.2818
# [87]	validation_0-error:0.2818
# [88]	validation_0-error:0.2818
# [89]	validation_0-error:0.285714
# [90]	validation_0-error:0.287671
# [91]	validation_0-error:0.287671
# [92]	validation_0-error:0.285714
# [93]	validation_0-error:0.291585
# [94]	validation_0-error:0.287671
# [95]	validation_0-error:0.283757
# [96]	validation_0-error:0.285714
# [97]	validation_0-error:0.285714
# [98]	validation_0-error:0.283757
# [99]	validation_0-error:0.283757
# [100]	validation_0-error:0.283757
# [101]	validation_0-error:0.283757
# [102]	validation_0-error:0.283757
# [103]	validation_0-error:0.285714
# [104]	validation_0-error:0.289628
# [105]	validation_0-error:0.289628
# [106]	validation_0-error:0.287671
# [107]	validation_0-error:0.287671
# [108]	validation_0-error:0.287671
# [109]	validation_0-error:0.287671
# [110]	validation_0-error:0.287671
# [111]	validation_0-error:0.285714
# [112]	validation_0-error:0.285714
# [113]	validation_0-error:0.285714
# [114]	validation_0-error:0.2818
# [115]	validation_0-error:0.2818
# [116]	validation_0-error:0.277887
# [117]	validation_0-error:0.279843
# [118]	validation_0-error:0.279843
# [119]	validation_0-error:0.279843
# [120]	validation_0-error:0.2818
# [121]	validation_0-error:0.279843
# [122]	validation_0-error:0.279843
# [123]	validation_0-error:0.2818
# [124]	validation_0-error:0.283757
# [125]	validation_0-error:0.283757
# [126]	validation_0-error:0.285714
# [127]	validation_0-error:0.285714
# [128]	validation_0-error:0.287671
# [129]	validation_0-error:0.283757
# [130]	validation_0-error:0.283757
# [131]	validation_0-error:0.285714
# [132]	validation_0-error:0.283757
# [133]	validation_0-error:0.283757
# [134]	validation_0-error:0.283757
# [135]	validation_0-error:0.283757
# [136]	validation_0-error:0.283757
# [137]	validation_0-error:0.285714
# [138]	validation_0-error:0.285714
# [139]	validation_0-error:0.277887
# [140]	validation_0-error:0.2818
# [141]	validation_0-error:0.277887
# [142]	validation_0-error:0.277887
# [143]	validation_0-error:0.273973
# [144]	validation_0-error:0.27593
# [145]	validation_0-error:0.277887
# [146]	validation_0-error:0.27593
# [147]	validation_0-error:0.27593
# [148]	validation_0-error:0.2818
# [149]	validation_0-error:0.279843
# [150]	validation_0-error:0.27593
# [151]	validation_0-error:0.277887
# [152]	validation_0-error:0.273973
# [153]	validation_0-error:0.273973
# [154]	validation_0-error:0.273973
# Stopping. Best iteration:
# [54]	validation_0-error:0.268102
#
# [0]	validation_0-error:0.320939
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.320939
# [2]	validation_0-error:0.313112
# [3]	validation_0-error:0.311155
# [4]	validation_0-error:0.305284
# [5]	validation_0-error:0.299413
# [6]	validation_0-error:0.305284
# [7]	validation_0-error:0.305284
# [8]	validation_0-error:0.311155
# [9]	validation_0-error:0.311155
# [10]	validation_0-error:0.313112
# [11]	validation_0-error:0.311155
# [12]	validation_0-error:0.309198
# [13]	validation_0-error:0.305284
# [14]	validation_0-error:0.305284
# [15]	validation_0-error:0.305284
# [16]	validation_0-error:0.307241
# [17]	validation_0-error:0.303327
# [18]	validation_0-error:0.303327
# [19]	validation_0-error:0.303327
# [20]	validation_0-error:0.303327
# [21]	validation_0-error:0.30137
# [22]	validation_0-error:0.30137
# [23]	validation_0-error:0.303327
# [24]	validation_0-error:0.30137
# [25]	validation_0-error:0.305284
# [26]	validation_0-error:0.303327
# [27]	validation_0-error:0.299413
# [28]	validation_0-error:0.299413
# [29]	validation_0-error:0.299413
# [30]	validation_0-error:0.293542
# [31]	validation_0-error:0.287671
# [32]	validation_0-error:0.293542
# [33]	validation_0-error:0.287671
# [34]	validation_0-error:0.289628
# [35]	validation_0-error:0.287671
# [36]	validation_0-error:0.295499
# [37]	validation_0-error:0.295499
# [38]	validation_0-error:0.297456
# [39]	validation_0-error:0.299413
# [40]	validation_0-error:0.297456
# [41]	validation_0-error:0.299413
# [42]	validation_0-error:0.297456
# [43]	validation_0-error:0.297456
# [44]	validation_0-error:0.297456
# [45]	validation_0-error:0.30137
# [46]	validation_0-error:0.303327
# [47]	validation_0-error:0.303327
# [48]	validation_0-error:0.303327
# [49]	validation_0-error:0.303327
# [50]	validation_0-error:0.305284
# [51]	validation_0-error:0.305284
# [52]	validation_0-error:0.305284
# [53]	validation_0-error:0.305284
# [54]	validation_0-error:0.30137
# [55]	validation_0-error:0.299413
# [56]	validation_0-error:0.297456
# [57]	validation_0-error:0.299413
# [58]	validation_0-error:0.30137
# [59]	validation_0-error:0.303327
# [60]	validation_0-error:0.303327
# [61]	validation_0-error:0.30137
# [62]	validation_0-error:0.30137
# [63]	validation_0-error:0.30137
# [64]	validation_0-error:0.299413
# [65]	validation_0-error:0.299413
# [66]	validation_0-error:0.299413
# [67]	validation_0-error:0.299413
# [68]	validation_0-error:0.297456
# [69]	validation_0-error:0.303327
# [70]	validation_0-error:0.297456
# [71]	validation_0-error:0.30137
# [72]	validation_0-error:0.293542
# [73]	validation_0-error:0.299413
# [74]	validation_0-error:0.30137
# [75]	validation_0-error:0.303327
# [76]	validation_0-error:0.299413
# [77]	validation_0-error:0.297456
# [78]	validation_0-error:0.299413
# [79]	validation_0-error:0.299413
# [80]	validation_0-error:0.299413
# [81]	validation_0-error:0.299413
# [82]	validation_0-error:0.30137
# [83]	validation_0-error:0.299413
# [84]	validation_0-error:0.295499
# [85]	validation_0-error:0.295499
# [86]	validation_0-error:0.295499
# [87]	validation_0-error:0.291585
# [88]	validation_0-error:0.289628
# [89]	validation_0-error:0.295499
# [90]	validation_0-error:0.295499
# [91]	validation_0-error:0.295499
# [92]	validation_0-error:0.297456
# [93]	validation_0-error:0.297456
# [94]	validation_0-error:0.295499
# [95]	validation_0-error:0.295499
# [96]	validation_0-error:0.299413
# [97]	validation_0-error:0.297456
# [98]	validation_0-error:0.299413
# [99]	validation_0-error:0.30137
# [100]	validation_0-error:0.295499
# [101]	validation_0-error:0.295499
# [102]	validation_0-error:0.295499
# [103]	validation_0-error:0.295499
# [104]	validation_0-error:0.293542
# [105]	validation_0-error:0.295499
# [106]	validation_0-error:0.295499
# [107]	validation_0-error:0.293542
# [108]	validation_0-error:0.293542
# [109]	validation_0-error:0.295499
# [110]	validation_0-error:0.297456
# [111]	validation_0-error:0.295499
# [112]	validation_0-error:0.295499
# [113]	validation_0-error:0.295499
# [114]	validation_0-error:0.295499
# [115]	validation_0-error:0.295499
# [116]	validation_0-error:0.295499
# [117]	validation_0-error:0.299413
# [118]	validation_0-error:0.30137
# [119]	validation_0-error:0.307241
# [120]	validation_0-error:0.305284
# [121]	validation_0-error:0.303327
# [122]	validation_0-error:0.305284
# [123]	validation_0-error:0.305284
# [124]	validation_0-error:0.307241
# [125]	validation_0-error:0.307241
# [126]	validation_0-error:0.297456
# [127]	validation_0-error:0.297456
# [128]	validation_0-error:0.299413
# [129]	validation_0-error:0.299413
# [130]	validation_0-error:0.297456
# [131]	validation_0-error:0.297456
# Stopping. Best iteration:
# [31]	validation_0-error:0.287671
#
# [0]	validation_0-error:0.332681
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.317025
# [2]	validation_0-error:0.30137
# [3]	validation_0-error:0.305284
# [4]	validation_0-error:0.317025
# [5]	validation_0-error:0.317025
# [6]	validation_0-error:0.303327
# [7]	validation_0-error:0.305284
# [8]	validation_0-error:0.30137
# [9]	validation_0-error:0.297456
# [10]	validation_0-error:0.291585
# [11]	validation_0-error:0.295499
# [12]	validation_0-error:0.297456
# [13]	validation_0-error:0.303327
# [14]	validation_0-error:0.299413
# [15]	validation_0-error:0.30137
# [16]	validation_0-error:0.297456
# [17]	validation_0-error:0.297456
# [18]	validation_0-error:0.297456
# [19]	validation_0-error:0.295499
# [20]	validation_0-error:0.299413
# [21]	validation_0-error:0.299413
# [22]	validation_0-error:0.299413
# [23]	validation_0-error:0.30137
# [24]	validation_0-error:0.299413
# [25]	validation_0-error:0.297456
# [26]	validation_0-error:0.295499
# [27]	validation_0-error:0.297456
# [28]	validation_0-error:0.30137
# [29]	validation_0-error:0.303327
# [30]	validation_0-error:0.295499
# [31]	validation_0-error:0.297456
# [32]	validation_0-error:0.30137
# [33]	validation_0-error:0.305284
# [34]	validation_0-error:0.305284
# [35]	validation_0-error:0.311155
# [36]	validation_0-error:0.307241
# [37]	validation_0-error:0.30137
# [38]	validation_0-error:0.303327
# [39]	validation_0-error:0.299413
# [40]	validation_0-error:0.293542
# [41]	validation_0-error:0.295499
# [42]	validation_0-error:0.297456
# [43]	validation_0-error:0.295499
# [44]	validation_0-error:0.293542
# [45]	validation_0-error:0.295499
# [46]	validation_0-error:0.293542
# [47]	validation_0-error:0.291585
# [48]	validation_0-error:0.289628
# [49]	validation_0-error:0.289628
# [50]	validation_0-error:0.287671
# [51]	validation_0-error:0.283757
# [52]	validation_0-error:0.279843
# [53]	validation_0-error:0.279843
# [54]	validation_0-error:0.279843
# [55]	validation_0-error:0.2818
# [56]	validation_0-error:0.289628
# [57]	validation_0-error:0.291585
# [58]	validation_0-error:0.287671
# [59]	validation_0-error:0.289628
# [60]	validation_0-error:0.289628
# [61]	validation_0-error:0.289628
# [62]	validation_0-error:0.289628
# [63]	validation_0-error:0.289628
# [64]	validation_0-error:0.289628
# [65]	validation_0-error:0.287671
# [66]	validation_0-error:0.293542
# [67]	validation_0-error:0.289628
# [68]	validation_0-error:0.291585
# [69]	validation_0-error:0.293542
# [70]	validation_0-error:0.293542
# [71]	validation_0-error:0.293542
# [72]	validation_0-error:0.295499
# [73]	validation_0-error:0.295499
# [74]	validation_0-error:0.295499
# [75]	validation_0-error:0.289628
# [76]	validation_0-error:0.289628
# [77]	validation_0-error:0.291585
# [78]	validation_0-error:0.293542
# [79]	validation_0-error:0.291585
# [80]	validation_0-error:0.291585
# [81]	validation_0-error:0.295499
# [82]	validation_0-error:0.297456
# [83]	validation_0-error:0.30137
# [84]	validation_0-error:0.303327
# [85]	validation_0-error:0.299413
# [86]	validation_0-error:0.295499
# [87]	validation_0-error:0.299413
# [88]	validation_0-error:0.295499
# [89]	validation_0-error:0.297456
# [90]	validation_0-error:0.299413
# [91]	validation_0-error:0.297456
# [92]	validation_0-error:0.295499
# [93]	validation_0-error:0.299413
# [94]	validation_0-error:0.299413
# [95]	validation_0-error:0.299413
# [96]	validation_0-error:0.30137
# [97]	validation_0-error:0.297456
# [98]	validation_0-error:0.299413
# [99]	validation_0-error:0.303327
# [100]	validation_0-error:0.299413
# [101]	validation_0-error:0.299413
# [102]	validation_0-error:0.30137
# [103]	validation_0-error:0.299413
# [104]	validation_0-error:0.295499
# [105]	validation_0-error:0.295499
# [106]	validation_0-error:0.297456
# [107]	validation_0-error:0.30137
# [108]	validation_0-error:0.305284
# [109]	validation_0-error:0.307241
# [110]	validation_0-error:0.307241
# [111]	validation_0-error:0.309198
# [112]	validation_0-error:0.309198
# [113]	validation_0-error:0.297456
# [114]	validation_0-error:0.295499
# [115]	validation_0-error:0.307241
# [116]	validation_0-error:0.309198
# [117]	validation_0-error:0.313112
# [118]	validation_0-error:0.313112
# [119]	validation_0-error:0.313112
# [120]	validation_0-error:0.311155
# [121]	validation_0-error:0.313112
# [122]	validation_0-error:0.313112
# [123]	validation_0-error:0.313112
# [124]	validation_0-error:0.315068
# [125]	validation_0-error:0.315068
# [126]	validation_0-error:0.315068
# [127]	validation_0-error:0.313112
# [128]	validation_0-error:0.313112
# [129]	validation_0-error:0.315068
# [130]	validation_0-error:0.307241
# [131]	validation_0-error:0.309198
# [132]	validation_0-error:0.307241
# [133]	validation_0-error:0.307241
# [134]	validation_0-error:0.307241
# [135]	validation_0-error:0.309198
# [136]	validation_0-error:0.307241
# [137]	validation_0-error:0.305284
# [138]	validation_0-error:0.307241
# [139]	validation_0-error:0.309198
# [140]	validation_0-error:0.309198
# [141]	validation_0-error:0.307241
# [142]	validation_0-error:0.307241
# [143]	validation_0-error:0.307241
# [144]	validation_0-error:0.305284
# [145]	validation_0-error:0.305284
# [146]	validation_0-error:0.305284
# [147]	validation_0-error:0.307241
# [148]	validation_0-error:0.30137
# [149]	validation_0-error:0.30137
# [150]	validation_0-error:0.30137
# [151]	validation_0-error:0.303327
# [152]	validation_0-error:0.307241
# Stopping. Best iteration:
# [52]	validation_0-error:0.279843
#
# [0]	validation_0-error:0.340509
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.313112
# [2]	validation_0-error:0.322896
# [3]	validation_0-error:0.318982
# [4]	validation_0-error:0.318982
# [5]	validation_0-error:0.311155
# [6]	validation_0-error:0.313112
# [7]	validation_0-error:0.309198
# [8]	validation_0-error:0.305284
# [9]	validation_0-error:0.317025
# [10]	validation_0-error:0.315068
# [11]	validation_0-error:0.305284
# [12]	validation_0-error:0.309198
# [13]	validation_0-error:0.313112
# [14]	validation_0-error:0.307241
# [15]	validation_0-error:0.309198
# [16]	validation_0-error:0.305284
# [17]	validation_0-error:0.305284
# [18]	validation_0-error:0.305284
# [19]	validation_0-error:0.305284
# [20]	validation_0-error:0.309198
# [21]	validation_0-error:0.305284
# [22]	validation_0-error:0.311155
# [23]	validation_0-error:0.305284
# [24]	validation_0-error:0.305284
# [25]	validation_0-error:0.295499
# [26]	validation_0-error:0.299413
# [27]	validation_0-error:0.293542
# [28]	validation_0-error:0.293542
# [29]	validation_0-error:0.293542
# [30]	validation_0-error:0.287671
# [31]	validation_0-error:0.287671
# [32]	validation_0-error:0.293542
# [33]	validation_0-error:0.293542
# [34]	validation_0-error:0.291585
# [35]	validation_0-error:0.291585
# [36]	validation_0-error:0.289628
# [37]	validation_0-error:0.291585
# [38]	validation_0-error:0.289628
# [39]	validation_0-error:0.291585
# [40]	validation_0-error:0.287671
# [41]	validation_0-error:0.287671
# [42]	validation_0-error:0.293542
# [43]	validation_0-error:0.291585
# [44]	validation_0-error:0.289628
# [45]	validation_0-error:0.291585
# [46]	validation_0-error:0.293542
# [47]	validation_0-error:0.287671
# [48]	validation_0-error:0.291585
# [49]	validation_0-error:0.289628
# [50]	validation_0-error:0.291585
# [51]	validation_0-error:0.291585
# [52]	validation_0-error:0.291585
# [53]	validation_0-error:0.289628
# [54]	validation_0-error:0.289628
# [55]	validation_0-error:0.285714
# [56]	validation_0-error:0.283757
# [57]	validation_0-error:0.283757
# [58]	validation_0-error:0.277887
# [59]	validation_0-error:0.277887
# [60]	validation_0-error:0.279843
# [61]	validation_0-error:0.277887
# [62]	validation_0-error:0.2818
# [63]	validation_0-error:0.273973
# [64]	validation_0-error:0.273973
# [65]	validation_0-error:0.273973
# [66]	validation_0-error:0.277887
# [67]	validation_0-error:0.277887
# [68]	validation_0-error:0.277887
# [69]	validation_0-error:0.277887
# [70]	validation_0-error:0.277887
# [71]	validation_0-error:0.277887
# [72]	validation_0-error:0.277887
# [73]	validation_0-error:0.277887
# [74]	validation_0-error:0.27593
# [75]	validation_0-error:0.279843
# [76]	validation_0-error:0.27593
# [77]	validation_0-error:0.277887
# [78]	validation_0-error:0.277887
# [79]	validation_0-error:0.277887
# [80]	validation_0-error:0.272016
# [81]	validation_0-error:0.27593
# [82]	validation_0-error:0.277887
# [83]	validation_0-error:0.279843
# [84]	validation_0-error:0.277887
# [85]	validation_0-error:0.279843
# [86]	validation_0-error:0.27593
# [87]	validation_0-error:0.27593
# [88]	validation_0-error:0.27593
# [89]	validation_0-error:0.277887
# [90]	validation_0-error:0.277887
# [91]	validation_0-error:0.279843
# [92]	validation_0-error:0.279843
# [93]	validation_0-error:0.279843
# [94]	validation_0-error:0.279843
# [95]	validation_0-error:0.279843
# [96]	validation_0-error:0.273973
# [97]	validation_0-error:0.277887
# [98]	validation_0-error:0.277887
# [99]	validation_0-error:0.279843
# [100]	validation_0-error:0.2818
# [101]	validation_0-error:0.283757
# [102]	validation_0-error:0.285714
# [103]	validation_0-error:0.283757
# [104]	validation_0-error:0.283757
# [105]	validation_0-error:0.2818
# [106]	validation_0-error:0.279843
# [107]	validation_0-error:0.279843
# [108]	validation_0-error:0.2818
# [109]	validation_0-error:0.285714
# [110]	validation_0-error:0.279843
# [111]	validation_0-error:0.277887
# [112]	validation_0-error:0.279843
# [113]	validation_0-error:0.279843
# [114]	validation_0-error:0.277887
# [115]	validation_0-error:0.277887
# [116]	validation_0-error:0.2818
# [117]	validation_0-error:0.2818
# [118]	validation_0-error:0.283757
# [119]	validation_0-error:0.283757
# [120]	validation_0-error:0.283757
# [121]	validation_0-error:0.279843
# [122]	validation_0-error:0.277887
# [123]	validation_0-error:0.277887
# [124]	validation_0-error:0.273973
# [125]	validation_0-error:0.277887
# [126]	validation_0-error:0.277887
# [127]	validation_0-error:0.272016
# [128]	validation_0-error:0.272016
# [129]	validation_0-error:0.273973
# [130]	validation_0-error:0.273973
# [131]	validation_0-error:0.273973
# [132]	validation_0-error:0.277887
# [133]	validation_0-error:0.273973
# [134]	validation_0-error:0.27593
# [135]	validation_0-error:0.27593
# [136]	validation_0-error:0.277887
# [137]	validation_0-error:0.277887
# [138]	validation_0-error:0.277887
# [139]	validation_0-error:0.27593
# [140]	validation_0-error:0.273973
# [141]	validation_0-error:0.270059
# [142]	validation_0-error:0.272016
# [143]	validation_0-error:0.270059
# [144]	validation_0-error:0.273973
# [145]	validation_0-error:0.273973
# [146]	validation_0-error:0.27593
# [147]	validation_0-error:0.27593
# [148]	validation_0-error:0.27593
# [149]	validation_0-error:0.273973
# [150]	validation_0-error:0.273973
# [151]	validation_0-error:0.273973
# [152]	validation_0-error:0.273973
# [153]	validation_0-error:0.273973
# [154]	validation_0-error:0.273973
# [155]	validation_0-error:0.273973
# [156]	validation_0-error:0.273973
# [157]	validation_0-error:0.27593
# [158]	validation_0-error:0.27593
# [159]	validation_0-error:0.27593
# [160]	validation_0-error:0.27593
# [161]	validation_0-error:0.273973
# [162]	validation_0-error:0.27593
# [163]	validation_0-error:0.272016
# [164]	validation_0-error:0.273973
# [165]	validation_0-error:0.273973
# [166]	validation_0-error:0.27593
# [167]	validation_0-error:0.272016
# [168]	validation_0-error:0.273973
# [169]	validation_0-error:0.273973
# [170]	validation_0-error:0.273973
# [171]	validation_0-error:0.273973
# [172]	validation_0-error:0.270059
# [173]	validation_0-error:0.270059
# [174]	validation_0-error:0.272016
# [175]	validation_0-error:0.270059
# [176]	validation_0-error:0.272016
# [177]	validation_0-error:0.272016
# [178]	validation_0-error:0.272016
# [179]	validation_0-error:0.273973
# [180]	validation_0-error:0.273973
# [181]	validation_0-error:0.27593
# [182]	validation_0-error:0.27593
# [183]	validation_0-error:0.270059
# [184]	validation_0-error:0.270059
# [185]	validation_0-error:0.268102
# [186]	validation_0-error:0.270059
# [187]	validation_0-error:0.268102
# [188]	validation_0-error:0.270059
# [189]	validation_0-error:0.270059
# [190]	validation_0-error:0.270059
# [191]	validation_0-error:0.273973
# [192]	validation_0-error:0.270059
# [193]	validation_0-error:0.270059
# [194]	validation_0-error:0.272016
# [195]	validation_0-error:0.272016
# [196]	validation_0-error:0.273973
# [197]	validation_0-error:0.272016
# [198]	validation_0-error:0.272016
# [199]	validation_0-error:0.270059
# [200]	validation_0-error:0.270059
# [201]	validation_0-error:0.27593
# [202]	validation_0-error:0.27593
# [203]	validation_0-error:0.27593
# [204]	validation_0-error:0.277887
# [205]	validation_0-error:0.277887
# [206]	validation_0-error:0.2818
# [207]	validation_0-error:0.2818
# [208]	validation_0-error:0.285714
# [209]	validation_0-error:0.285714
# [210]	validation_0-error:0.2818
# [211]	validation_0-error:0.283757
# [212]	validation_0-error:0.285714
# [213]	validation_0-error:0.2818
# [214]	validation_0-error:0.2818
# [215]	validation_0-error:0.2818
# [216]	validation_0-error:0.279843
# [217]	validation_0-error:0.279843
# [218]	validation_0-error:0.2818
# [219]	validation_0-error:0.277887
# [220]	validation_0-error:0.27593
# [221]	validation_0-error:0.277887
# [222]	validation_0-error:0.279843
# [223]	validation_0-error:0.279843
# [224]	validation_0-error:0.2818
# [225]	validation_0-error:0.2818
# [226]	validation_0-error:0.285714
# [227]	validation_0-error:0.285714
# [228]	validation_0-error:0.285714
# [229]	validation_0-error:0.287671
# [230]	validation_0-error:0.289628
# [231]	validation_0-error:0.287671
# [232]	validation_0-error:0.289628
# [233]	validation_0-error:0.287671
# [234]	validation_0-error:0.285714
# [235]	validation_0-error:0.287671
# [236]	validation_0-error:0.285714
# [237]	validation_0-error:0.285714
# [238]	validation_0-error:0.287671
# [239]	validation_0-error:0.291585
# [240]	validation_0-error:0.289628
# [241]	validation_0-error:0.287671
# [242]	validation_0-error:0.285714
# [243]	validation_0-error:0.285714
# [244]	validation_0-error:0.285714
# [245]	validation_0-error:0.285714
# [246]	validation_0-error:0.285714
# [247]	validation_0-error:0.283757
# [248]	validation_0-error:0.285714
# [249]	validation_0-error:0.283757
# [250]	validation_0-error:0.285714
# [251]	validation_0-error:0.283757
# [252]	validation_0-error:0.283757
# [253]	validation_0-error:0.285714
# [254]	validation_0-error:0.285714
# [255]	validation_0-error:0.283757
# [256]	validation_0-error:0.279843
# [257]	validation_0-error:0.279843
# [258]	validation_0-error:0.2818
# [259]	validation_0-error:0.279843
# [260]	validation_0-error:0.277887
# [261]	validation_0-error:0.277887
# [262]	validation_0-error:0.277887
# [263]	validation_0-error:0.277887
# [264]	validation_0-error:0.279843
# [265]	validation_0-error:0.279843
# [266]	validation_0-error:0.279843
# [267]	validation_0-error:0.279843
# [268]	validation_0-error:0.279843
# [269]	validation_0-error:0.279843
# [270]	validation_0-error:0.2818
# [271]	validation_0-error:0.2818
# [272]	validation_0-error:0.2818
# [273]	validation_0-error:0.2818
# [274]	validation_0-error:0.2818
# [275]	validation_0-error:0.279843
# [276]	validation_0-error:0.283757
# [277]	validation_0-error:0.283757
# [278]	validation_0-error:0.287671
# [279]	validation_0-error:0.287671
# [280]	validation_0-error:0.285714
# [281]	validation_0-error:0.285714
# [282]	validation_0-error:0.285714
# [283]	validation_0-error:0.285714
# [284]	validation_0-error:0.283757
# [285]	validation_0-error:0.285714
# Stopping. Best iteration:
# [185]	validation_0-error:0.268102
#
# [0]	validation_0-error:0.35098
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.284314
# [2]	validation_0-error:0.354902
# [3]	validation_0-error:0.286275
# [4]	validation_0-error:0.3
# [5]	validation_0-error:0.303922
# [6]	validation_0-error:0.309804
# [7]	validation_0-error:0.3
# [8]	validation_0-error:0.311765
# [9]	validation_0-error:0.3
# [10]	validation_0-error:0.309804
# [11]	validation_0-error:0.301961
# [12]	validation_0-error:0.296078
# [13]	validation_0-error:0.301961
# [14]	validation_0-error:0.305882
# [15]	validation_0-error:0.303922
# [16]	validation_0-error:0.301961
# [17]	validation_0-error:0.301961
# [18]	validation_0-error:0.301961
# [19]	validation_0-error:0.3
# [20]	validation_0-error:0.3
# [21]	validation_0-error:0.309804
# [22]	validation_0-error:0.301961
# [23]	validation_0-error:0.3
# [24]	validation_0-error:0.298039
# [25]	validation_0-error:0.301961
# [26]	validation_0-error:0.307843
# [27]	validation_0-error:0.294118
# [28]	validation_0-error:0.301961
# [29]	validation_0-error:0.305882
# [30]	validation_0-error:0.298039
# [31]	validation_0-error:0.303922
# [32]	validation_0-error:0.3
# [33]	validation_0-error:0.298039
# [34]	validation_0-error:0.298039
# [35]	validation_0-error:0.3
# [36]	validation_0-error:0.294118
# [37]	validation_0-error:0.296078
# [38]	validation_0-error:0.296078
# [39]	validation_0-error:0.292157
# [40]	validation_0-error:0.290196
# [41]	validation_0-error:0.292157
# [42]	validation_0-error:0.292157
# [43]	validation_0-error:0.288235
# [44]	validation_0-error:0.290196
# [45]	validation_0-error:0.290196
# [46]	validation_0-error:0.292157
# [47]	validation_0-error:0.294118
# [48]	validation_0-error:0.298039
# [49]	validation_0-error:0.296078
# [50]	validation_0-error:0.3
# [51]	validation_0-error:0.298039
# [52]	validation_0-error:0.298039
# [53]	validation_0-error:0.294118
# [54]	validation_0-error:0.292157
# [55]	validation_0-error:0.292157
# [56]	validation_0-error:0.288235
# [57]	validation_0-error:0.288235
# [58]	validation_0-error:0.290196
# [59]	validation_0-error:0.292157
# [60]	validation_0-error:0.294118
# [61]	validation_0-error:0.3
# [62]	validation_0-error:0.3
# [63]	validation_0-error:0.298039
# [64]	validation_0-error:0.298039
# [65]	validation_0-error:0.298039
# [66]	validation_0-error:0.3
# [67]	validation_0-error:0.3
# [68]	validation_0-error:0.3
# [69]	validation_0-error:0.298039
# [70]	validation_0-error:0.298039
# [71]	validation_0-error:0.298039
# [72]	validation_0-error:0.298039
# [73]	validation_0-error:0.296078
# [74]	validation_0-error:0.296078
# [75]	validation_0-error:0.296078
# [76]	validation_0-error:0.298039
# [77]	validation_0-error:0.296078
# [78]	validation_0-error:0.294118
# [79]	validation_0-error:0.292157
# [80]	validation_0-error:0.292157
# [81]	validation_0-error:0.292157
# [82]	validation_0-error:0.294118
# [83]	validation_0-error:0.292157
# [84]	validation_0-error:0.294118
# [85]	validation_0-error:0.294118
# [86]	validation_0-error:0.288235
# [87]	validation_0-error:0.288235
# [88]	validation_0-error:0.290196
# [89]	validation_0-error:0.290196
# [90]	validation_0-error:0.288235
# [91]	validation_0-error:0.288235
# [92]	validation_0-error:0.290196
# [93]	validation_0-error:0.288235
# [94]	validation_0-error:0.292157
# [95]	validation_0-error:0.292157
# [96]	validation_0-error:0.292157
# [97]	validation_0-error:0.294118
# [98]	validation_0-error:0.290196
# [99]	validation_0-error:0.288235
# [100]	validation_0-error:0.290196
# [101]	validation_0-error:0.292157
# Stopping. Best iteration:
# [1]	validation_0-error:0.284314
# [0.762678262028522,
#  0.750137154290509,
#  0.7507479058635819,
#  0.7486990316843423,
#  0.725734256661423]

# %%
model_list = [
    XGBClassifier(random_state=SEED), 
    LogisticRegression(random_state=SEED),
    RandomForestClassifier(random_state=SEED),
    MLPClassifier(random_state=SEED),
    LGBMClassifier(random_state=SEED)
]
for model in tqdm(model_list):
    model.fit(x_train,y_train)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
# pred_list = [] 
# for model in model_list:
#     pred = model.predict_proba(test)[:,1] 
#     # score = roc_auc_score(y_valid,pred)
#     # print(score) # 모델들의 성능 보기 비교해서 불필요한 모델은 걸래내자
#     pred_list.append(pred)
    
# # pred = np.mean(pred_list,axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
from itertools import combinations

# %%
best_score = 0 
for i in range(2, len(model_list)): # 2~model_list 만큼 비교하겠다.
    for models in combinations(model_list, i):

        preds = [ model.predict_proba(x_valid)[:,1] for model in models]
        pred = np.mean(preds,axis=0) 
        score = roc_auc_score(y_valid,pred) 
        if best_score < score: 
            best_score = score 
            best_models = models
best_score
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# 0.7743143964580529

# %%
best_models
# Out:
# (XGBClassifier(random_state=42),
#  LogisticRegression(random_state=42),
#  RandomForestClassifier(random_state=42))

# %%
pred_list =[]
for model in best_models:
    pred = model.predict_proba(test)[:,1]
    pred_list.append(pred)
    # for j in len(best_models[i]):
    #     print(best_models[i][j])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
pred = np.mean(pred_list,axis=0)

# %%
sample_submission["target"] = pred
sample_submission
# Out:
#       고객번호    target
# 0    10001  0.602531
# 1    10070  0.448243
# 2    10075  0.325954
# 3    10086  0.358779
# 4    10128  0.609759
# ..     ...       ...
# 941  49903  0.503832
# 942  49918  0.158814
# 943  49937  0.476924
# 944  49949  0.296403
# 945  49992  0.086909
#
# [946 rows x 2 columns]

# %%
sample_submission.to_csv("submit.csv",index=False)
